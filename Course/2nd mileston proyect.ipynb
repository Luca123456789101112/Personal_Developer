# %%
from random import shuffle
palos = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Cards:
    def __init__(self, palo,rank):
        self.palo = palo
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.palo

# %%
class Deck:
    
    def __init__(self):
        
        self.all_cards = []
        
        for palo in palos:   
            for number in ranks:
                created_card = Cards(palo, number)
                self.all_cards.append(created_card)
    
    def shuffle(self):
        shuffle(self.all_cards)
    
    def deal_one(self):
        return self.all_cards.pop(0)

# %%
deck = Deck()

# %%
print(deck.all_cards[0])
# Out:
# Two of Hearts

# %%
class Player:
    
    def __init__(self, name):
        
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        f = deck.all_cards.pop(0)
        return self.all_cards.append(f)
    
    
    def add_cards(self):
        f = deck.deal_one()
        self.all_cards.append(f)
    
    def __str__(self):
        return f"Player {self.name} has {len(self.all_cards)} cards."
    
    def restart(self):
        self.all_cards = [ ]

# %%
player1 = Player(input("Player one name: "))
player2 = Player(input("Player two name: "))
# Out:
# Player one name:
# Player two name:

# %%
deck.shuffle()

# %%
print(deck.all_cards[0])
# Out:
# King of Clubs

# %%
game_on = True

while game_on:
    
    player1.restart()
    player2.restart()
    
    #Add the firsts two cards
    player1.add_cards()
    player1.add_cards()
    
    player2.add_cards()    
    player2.add_cards()
    
    pedir = " "
    
    twocards1 = True
    
    if player1.all_cards[0].value + player1.all_cards[1].value < 21:
        
        print(f"Card 1: {player1.all_cards[0].rank} of {player1.all_cards[0].palo}")
        
        print(" ")
        
        print(f"Card 2: {player1.all_cards[1].rank} of {player1.all_cards[1].palo}")
        
        print(" ")
        
        while pedir not in ["si", "no"]:
            
            pedir = input("Pedis o no pedis: ")
            print(" ")
            
        
        if pedir == "si":
            player1.add_cards()
            print(f"Card 1: {player1.all_cards[0].rank} of {player1.all_cards[0].palo}")
            
            print(" ")
            
            print(f"Card 2: {player1.all_cards[1].rank} of {player1.all_cards[1].palo}")
            
            print(" ")
            
            print(f"Card 3: {player1.all_cards[2].rank} of {player1.all_cards[2].palo}")
            
            print(" ")
            
            if player1.all_cards[0].value + player1.all_cards[1].value + player1.all_cards[2].value <= 21:
                print("Player 1 got:")
                print(player1.all_cards[0].value + player1.all_cards[1].value + player1.all_cards[2].value)
                print(" ")
            
                print("Now is turn for Player 2")
            
                print(" ")
                twocards1 = False
            else:
                print("Player one got more than 21")
                print(" ")
                print("Player 2 wins!!!")
                break
            
            
        if pedir == "no":
            
            print(" ")
            
            print("Player 1 got:")
            
            print(player1.all_cards[0].value + player1.all_cards[1].value)
            
            print(" ")
            
            print("Now is turn for Player 2")
            
            print(" ")
            
        pedir = " "
        
        
        if player2.all_cards[0].value + player2.all_cards[1].value < 21:
        
            print(f"Card 1: {player2.all_cards[0].rank} of {player2.all_cards[0].palo}")
            
            print(" ")
        
            print(f"Card 2: {player2.all_cards[1].rank} of {player2.all_cards[1].palo}")
            
            print(" ")
        
            while pedir not in ["si", "no"]:
            
                pedir = input("Pedis o no pedis: ")
                print(" ")

        twocards = True
        
        if pedir == "si":
            player2.add_cards()
            print(f"Card 1: {player2.all_cards[0].rank} of {player2.all_cards[0].palo}")
            
            print(" ")
            
            print(f"Card 2: {player2.all_cards[1].rank} of {player2.all_cards[1].palo}")
            
            print(" ")
            
            print(f"Card 3: {player2.all_cards[2].rank} of {player2.all_cards[2].palo}")
            
            print(" ")
            
            if player2.all_cards[0].value + player2.all_cards[1].value + player2.all_cards[2].value <= 21:
                print("Player 2 got:")
                print(player2.all_cards[0].value + player2.all_cards[1].value + player2.all_cards[2].value)
                twocards = False
            else:
                print("Player 2 got more than 21")
                print(" ")
                print("Player 1 wins!!!")
                break
            
            
        if pedir == "no":
            print("Player 2 got:")
            print(player2.all_cards[0].value + player2.all_cards[1].value)
            print(" ")
        
        if twocards == True and twocards1 == True:
        
            if player2.all_cards[0].value + player2.all_cards[1].value < player1.all_cards[0].value + player1.all_cards[1].value:
                print(" ")
                print("Player 1 has wone!!!")
                break
            else:
                print(" ")
                print("Player 2 has wone!!!")
                break
        elif twocards1 == False:
            if player2.all_cards[0].value + player2.all_cards[1].value < player1.all_cards[0].value + player1.all_cards[1].value + player1.all_cards[1].value + player1.all_cards[2].value:
                print(" ")
                print("Player 1 has wone!!!")
                break
            else:
                print(" ")
                print("Player 2 has wone!!!")
                break
        elif twocards == False:
            if player2.all_cards[0].value + player2.all_cards[1].value + player2.all_cards[2].value < player1.all_cards[0].value + player1.all_cards[1].value:
                print(" ")
                print("Player 1 has wone!!!")
                break
            else:
                print(" ")
                print("Player 2 has wone!!!")
                break
        else:
            if player2.all_cards[0].value + player2.all_cards[1].value + player2.all_cards[2].value < player1.all_cards[0].value + player1.all_cards[1].value + player1.all_cards[2].value:
                print(" ")
                print("Player 1 has wone!!!")
                break
            else:
                print(" ")
                print("Player 2 has wone!!!")
                break
        
        print("end of game")
        break
# Out:
# Card 1: Two of Spades
#
# Card 2: Six of Spades
#
# Pedis o no pedis: si
#
# Card 1: Two of Spades
#
# Card 2: Six of Spades
#
# Card 3: King of Diamonds
#
# Player 1 got:
# 21
#
# Now is turn for Player 2
#
# Card 1: Eight of Clubs
#
# Card 2: Six of Hearts
#
# Pedis o no pedis: si
#
# Card 1: Eight of Clubs
#
# Card 2: Six of Hearts
#
# Card 3: Two of Clubs
#
# Player 2 got:
# 16
#
# Player 1 has wone!!!
