# %%
import os
import collections
import re


class Computer_info():
    def __init__(self):
        pass
    
    def __str__(self):
        return "This is the computer info class"
    
    def file_counter(self,file_path):
        
        file_counter = 1
        
        for folder,sub_folders,files in os.walk(file_path):
            for f in files: 
                print(f"File Number: {file_counter}")
                print(f"\t File: {f}")
                file_counter += 1
                print("\n")
                
        print(f"Total of files in the path: {file_counter-1}")
    
    def subfol_counter(self,file_path):
        subfol_counter = 1
        
        for folders,sub_folders,files in os.walk(file_path):
            for sub in sub_folders: 
                print(f"Sub Folder Number: {subfol_counter}")
                print(f"\t Sub Folder: {sub}")
                subfol_counter += 1
                print("\n")
                
        print(f"Total of sub folders in the path: {subfol_counter-1}")
    
    def folder_counter(self,file_path):
        fol_counter = 1
        
        for folders,sub_folders,files in os.walk(file_path):
                print(f"Folder Number: {fol_counter}")
                print(f"\t Folder: {folders}")
                fol_counter += 1
                print("\n")
                
        print(f"Total of folders in the path: {fol_counter-1}")
    
    def general_look(self,file_path):
        
        for folders,sub_folders,files in os.walk(file_path):
            print(f"The folder you are looking at is: {folders}")
            print("\n")
            
            print("The subfolders inside are")
            for sub_folder in sub_folders:
                print(f"Sub_Folder: {sub_folder}")
                if len(sub_folder)==0:
                    print("None")
            
            print("\n")
            
            print("The files inside are:")
            for file in files:
                print(f"File: {file}")
                print("\n")
    
    def search_file(self,pattern):
        
        file_path = 'C:\\Users\\Luca\\Desktop\\Personal'
        results = []
        
        def search(file,patt=pattern):
            f = open(file,"r")
            text = f.read()

            if re.search != None:
                return re.search(patt,text)
            else:
                return ""
                
        for folders,sub_folders,files in os.walk(file_path):
            for f in files:
                full_path = folder+'\\'+f
         
                results.append(search(f)) 
        
        for r in results:
            if r != '':
                print(r.group())

# %%
CI_instance = Computer_info()

# %%
CI_instance.file_counter(file_path = 'C:\\Users\\Luca\\Desktop\\Personal')
# Out:
# File Number: 1
# 	 File: COMMIT_EDITMSG
#
#
# File Number: 2
# 	 File: config
#
#
# File Number: 3
# 	 File: description
#
#
# File Number: 4
# 	 File: HEAD
#
#
# File Number: 5
# 	 File: index
#
#
# File Number: 6
# 	 File: applypatch-msg.sample
#
#
# File Number: 7
# 	 File: commit-msg.sample
#
#
# File Number: 8
# 	 File: fsmonitor-watchman.sample
#
#
# File Number: 9
# 	 File: post-update.sample
#
#
# File Number: 10
# 	 File: pre-applypatch.sample
#
#
# File Number: 11
# 	 File: pre-commit.sample
#
#
# File Number: 12
# 	 File: pre-merge-commit.sample
#
#
# File Number: 13
# 	 File: pre-push.sample
#
#
# File Number: 14
# 	 File: pre-rebase.sample
#
#
# File Number: 15
# 	 File: pre-receive.sample
#
#
# File Number: 16
# 	 File: prepare-commit-msg.sample
#
#
# File Number: 17
# 	 File: push-to-checkout.sample
#
#
# File Number: 18
# 	 File: sendemail-validate.sample
#
#
# File Number: 19
# 	 File: update.sample
#
#
# File Number: 20
# 	 File: exclude
#
#
# File Number: 21
# ...
